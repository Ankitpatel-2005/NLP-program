# %%
import nltk
from nltk.tokenize import sent_tokenize

nltk.download('punkt_tab')

text = "Natural Language Processing is interesting. NLTK is a popular NLP library."

sentences = sent_tokenize(text)

print(sentences)
# Out:
# ['Natural Language Processing is interesting.', 'NLTK is a popular NLP library.']
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %%
from nltk.tokenize import word_tokenize

text = "Natural Language Processing is interesting!"

words = word_tokenize(text)

print(words)
# Out:
# ['Natural', 'Language', 'Processing', 'is', 'interesting', '!']

# %%
# !pip install spacy
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 73.0 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import spacy

nlp = spacy.load("en_core_web_sm")

text = "Natural Language Processing is interesting. spaCy is another NLP library."

doc = nlp(text)

# Sentence tokenization
sentences = [sent.text for sent in doc.sents]
print(sentences)

# Word tokenization
words = [token.text for token in doc]
print(words)
# Out:
# ['Natural Language Processing is interesting.', 'spaCy is another NLP library.']
# ['Natural', 'Language', 'Processing', 'is', 'interesting', '.', 'spaCy', 'is', 'another', 'NLP', 'library', '.']
